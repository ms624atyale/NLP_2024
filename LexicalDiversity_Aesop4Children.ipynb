# %% [markdown]
# <a href="https://colab.research.google.com/github/ms624atyale/NLP_2023/blob/main/LexicalDiversity_Aesop4Children.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/ms624atyale/Data_Class
# Out:
# Cloning into 'Data_Class'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 122 (delta 24), reused 25 (delta 6), pack-reused 69
# Receiving objects: 100% (122/122), 183.78 KiB | 6.81 MiB/s, done.
# Resolving deltas: 100% (60/60), done.

# %%
# %cd /content/Data_Class/PG Aesop NoQuotes
# Out:
# /content/Data_Class/PG Aesop NoQuotes

# %%
file = open("/content/sample_data/NoQuotesAllText.txt", 'rt')
txt = file.read()
print(txt)
file.close() #Using this close()function, you are no longer using your text file of the current workingdirectory with open()function.
# Out:
# There was once a little Kid whose growing horns made him think he was a grown-up Billy Goat and able to take care of himself. So one evening when the flock started home from the pasture and his mother called, the Kid paid no heed and kept right on nibbling the tender grass. A little later when he lifted his head, the flock was gone. He was all alone. The sun was sinking. Long shadows came creeping over the ground. A chilly little wind came creeping with them making scary noises in the grass. The Kid shivered as he thought of the terrible Wolf. Then he started wildly over the field, bleating for his mother. But not half-way, near a clump of trees, there was the Wolf! The Kid knew there was little hope for him. Please, Mr. Wolf, he said trembling, I know you are going to eat me. But first please pipe me a tune, for I want to dance and be merry as long as I can.The Wolf liked the idea of a little music before eating, so he struck up a merry tune and the Kid leaped and frisked gaily. Mea
# ...

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import sent_tokenize
sentence = sent_tokenize(txt)
print('Sentence Tokenized: %s' %sentence)
# Out:
# Sentence Tokenized: ['There was once a little Kid whose growing horns made him think he was a grown-up Billy Goat and able to take care of himself.', 'So one evening when the flock started home from the pasture and his mother called, the Kid paid no heed and kept right on nibbling the tender grass.', 'A little later when he lifted his head, the flock was gone.', 'He was all alone.', 'The sun was sinking.', 'Long shadows came creeping over the ground.', 'A chilly little wind came creeping with them making scary noises in the grass.', 'The Kid shivered as he thought of the terrible Wolf.', 'Then he started wildly over the field, bleating for his mother.', 'But not half-way, near a clump of trees, there was the Wolf!', 'The Kid knew there was little hope for him.', 'Please, Mr. Wolf, he said trembling, I know you are going to eat me.', 'But first please pipe me a tune, for I want to dance and be merry as long as I can.The Wolf liked the idea of a little music before eating, so he struck
# ...

# %% [markdown]
# New Session

# %%
file = open("/content/sample_data/NoQuotesAllText.txt", 'rt')

obj = file.read().replace("\n"," ")
obj.split()
# Out:
# ['There',
#  'was',
#  'once',
#  'a',
#  'little',
#  'Kid',
#  'whose',
#  'growing',
#  'horns',
#  'made',
#  'him',
#  'think',
#  'he',
#  'was',
#  'a',
#  'grown-up',
#  'Billy',
#  'Goat',
#  'and',
#  'able',
#  'to',
#  'take',
#  'care',
#  'of',
#  'himself.',
#  'So',
#  'one',
#  'evening',
#  'when',
#  'the',
#  'flock',
#  'started',
#  'home',
#  'from',
#  'the',
#  'pasture',
#  'and',
#  'his',
#  'mother',
#  'called,',
#  'the',
#  'Kid',
#  'paid',
#  'no',
#  'heed',
#  'and',
#  'kept',
#  'right',
#  'on',
#  'nibbling',
#  'the',
#  'tender',
#  'grass.',
#  'A',
#  'little',
#  'later',
#  'when',
#  'he',
#  'lifted',
#  'his',
#  'head,',
#  'the',
#  'flock',
#  'was',
#  'gone.',
#  'He',
#  'was',
#  'all',
#  'alone.',
#  'The',
#  'sun',
#  'was',
#  'sinking.',
#  'Long',
#  'shadows',
#  'came',
#  'creeping',
#  'over',
#  'the',
#  'ground.',
#  'A',
#  'chilly',
#  'little',
#  'wind',
#  'came',
#  'creeping',
#  'with',
#  'them',
# ...

# %% [markdown]
# Function.	Type	symbols or words	result	example
# RegexpTokenizer()	punctuation	".", ",", "?", "!", ";", ":"	deleted
# apostrophe	"'"	deleted
# word-linking hyphen	"-"	deleted
# phrase-linking hyphen	"--"	deleted
# Capital vs. small	The ones	tokenize	'The', 'ones'
# they're, were having		'they', 're', 'were', 'hav'

# %%
file = open("/content/sample_data/NoQuotesAllText.txt", 'rt')

from nltk.tokenize import RegexpTokenizer
retokenize = RegexpTokenizer("[\w]+")
result = retokenize.tokenize(obj)

print('Tokenizing Words with RegexpTokenizer: %s' %result)
# Out:
# Tokenizing Words with RegexpTokenizer: ['There', 'was', 'once', 'a', 'little', 'Kid', 'whose', 'growing', 'horns', 'made', 'him', 'think', 'he', 'was', 'a', 'grown', 'up', 'Billy', 'Goat', 'and', 'able', 'to', 'take', 'care', 'of', 'himself', 'So', 'one', 'evening', 'when', 'the', 'flock', 'started', 'home', 'from', 'the', 'pasture', 'and', 'his', 'mother', 'called', 'the', 'Kid', 'paid', 'no', 'heed', 'and', 'kept', 'right', 'on', 'nibbling', 'the', 'tender', 'grass', 'A', 'little', 'later', 'when', 'he', 'lifted', 'his', 'head', 'the', 'flock', 'was', 'gone', 'He', 'was', 'all', 'alone', 'The', 'sun', 'was', 'sinking', 'Long', 'shadows', 'came', 'creeping', 'over', 'the', 'ground', 'A', 'chilly', 'little', 'wind', 'came', 'creeping', 'with', 'them', 'making', 'scary', 'noises', 'in', 'the', 'grass', 'The', 'Kid', 'shivered', 'as', 'he', 'thought', 'of', 'the', 'terrible', 'Wolf', 'Then', 'he', 'started', 'wildly', 'over', 'the', 'field', 'bleating', 'for', 'his', 'mother', 'But', '
# ...

# %%
import re
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld

with open("/content/sample_data/NoQuotesAllText.txt", 'rt') as file:
    file_content = file.read()

# Tokenize the content
tok = ld.tokenize(file_content)

#file = open("/content/sample_data/NoQuotesAllText.txt", 'rt')
#file.read()
#tok = ld.tokenize(file)

# %%
print(tok[:10])
# Out:
# ['there', 'was', 'once', 'a', 'little', 'kid', 'whose', 'growing', 'horns', 'made']

# %%
print(tok)
# Out:
# ['there', 'was', 'once', 'a', 'little', 'kid', 'whose', 'growing', 'horns', 'made', 'him', 'think', 'he', 'was', 'a', 'grownup', 'billy', 'goat', 'and', 'able', 'to', 'take', 'care', 'of', 'himself', 'so', 'one', 'evening', 'when', 'the', 'flock', 'started', 'home', 'from', 'the', 'pasture', 'and', 'his', 'mother', 'called', 'the', 'kid', 'paid', 'no', 'heed', 'and', 'kept', 'right', 'on', 'nibbling', 'the', 'tender', 'grass', 'a', 'little', 'later', 'when', 'he', 'lifted', 'his', 'head', 'the', 'flock', 'was', 'gone', 'he', 'was', 'all', 'alone', 'the', 'sun', 'was', 'sinking', 'long', 'shadows', 'came', 'creeping', 'over', 'the', 'ground', 'a', 'chilly', 'little', 'wind', 'came', 'creeping', 'with', 'them', 'making', 'scary', 'noises', 'in', 'the', 'grass', 'the', 'kid', 'shivered', 'as', 'he', 'thought', 'of', 'the', 'terrible', 'wolf', 'then', 'he', 'started', 'wildly', 'over', 'the', 'field', 'bleating', 'for', 'his', 'mother', 'but', 'not', 'halfway', 'near', 'a', 'clump', 'of'
# ...

# %%
flt = ld.flemmatize(file_content)

# %%
print(ld.ttr(flt))
# Out:
# 0.09809508939027246

# %% [markdown]
# Consider including eliminating stopwords if you can come up with something decent cause.
# - shortword = re.compile(r'\W*\b\w{1,3}\b') #Remove words less than 3 letters.
