# %% [markdown]
# <a href="https://colab.research.google.com/github/ms624atyale/NLP_2023/blob/main/4_4_WhileStatementwContinueBreak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python 200제 Unit 014

# %%
x = 0
while x < 10:
  x = x + 1
  if x < 3:
    continue
  print(x)
  if x > 7:
    break
# Out:
# 3
# 4
# 5
# 6
# 7
# 8

# %%
x = 1
total =0
while 1:
  total = total + x
  if total > 100000:
    print(x)
    print(total)
    break
  x = x + 1
# Out:
# 447
# 100128
